# %% [markdown]
#  # Business problem
# - creative a predicitve model that can help predict a species of a penguin based on physical attributes, then we can use that model to help researchers classify penguins in the field,instead of needing an experienced biologist

# %%
import numpy as np
import pandas as pd
import warnings
warnings.simplefilter('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\L.RAMYA\Downloads\penguins_size.csv")
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# # Data cleaning

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df['culmen_length_mm'] = df['culmen_length_mm'].fillna(df['culmen_length_mm'].mean())
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000             18.7              181.0
# 1    Adelie  Torgersen          39.50000             17.4              186.0
# 2    Adelie  Torgersen          40.30000             18.0              195.0
# 3    Adelie  Torgersen          43.92193              NaN                NaN
# 4    Adelie  Torgersen          36.70000             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193              NaN                NaN
# 340  Gentoo     Biscoe          46.80000             14.3              215.0
# 341  Gentoo     Biscoe          50.40000             15.7              222.0
# 342  Gentoo     Biscoe          45.20000             14.8              212.0
# 343  Gentoo     Biscoe          49.90000             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      0
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df['culmen_depth_mm'] = df['culmen_depth_mm'].fillna(df['culmen_depth_mm'].mean())
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000         18.70000              181.0
# 1    Adelie  Torgersen          39.50000         17.40000              186.0
# 2    Adelie  Torgersen          40.30000         18.00000              195.0
# 3    Adelie  Torgersen          43.92193         17.15117                NaN
# 4    Adelie  Torgersen          36.70000         19.30000              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193         17.15117                NaN
# 340  Gentoo     Biscoe          46.80000         14.30000              215.0
# 341  Gentoo     Biscoe          50.40000         15.70000              222.0
# 342  Gentoo     Biscoe          45.20000         14.80000              212.0
# 343  Gentoo     Biscoe          49.90000         16.10000              213.0
#
#      body_mass_g     sex
# ...

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      0
# culmen_depth_mm       0
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df['flipper_length_mm'] = df['flipper_length_mm'].fillna(df['flipper_length_mm'].mean())
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000         18.70000         181.000000
# 1    Adelie  Torgersen          39.50000         17.40000         186.000000
# 2    Adelie  Torgersen          40.30000         18.00000         195.000000
# 3    Adelie  Torgersen          43.92193         17.15117         200.915205
# 4    Adelie  Torgersen          36.70000         19.30000         193.000000
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193         17.15117         200.915205
# 340  Gentoo     Biscoe          46.80000         14.30000         215.000000
# 341  Gentoo     Biscoe          50.40000         15.70000         222.000000
# 342  Gentoo     Biscoe          45.20000         14.80000         212.000000
# 343  Gentoo     Biscoe          49.90000         16.10000         213.000000
#
#      body_mass_g     sex
# ...

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      0
# culmen_depth_mm       0
# flipper_length_mm     0
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df['body_mass_g'] = df['body_mass_g'].fillna(df['body_mass_g'].mean())
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000         18.70000         181.000000
# 1    Adelie  Torgersen          39.50000         17.40000         186.000000
# 2    Adelie  Torgersen          40.30000         18.00000         195.000000
# 3    Adelie  Torgersen          43.92193         17.15117         200.915205
# 4    Adelie  Torgersen          36.70000         19.30000         193.000000
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193         17.15117         200.915205
# 340  Gentoo     Biscoe          46.80000         14.30000         215.000000
# 341  Gentoo     Biscoe          50.40000         15.70000         222.000000
# 342  Gentoo     Biscoe          45.20000         14.80000         212.000000
# 343  Gentoo     Biscoe          49.90000         16.10000         213.000000
#
#      body_mass_g     sex
# ...

# %%
df.isna().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      0
# culmen_depth_mm       0
# flipper_length_mm     0
# body_mass_g           0
# sex                  10
# dtype: int64

# %%
df[df['sex']=='.']
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 336  Gentoo  Biscoe              44.5             15.7              217.0
#
#      body_mass_g sex
# 336       4875.0   .

# %%
df['sex'].replace('.','MALE',inplace=True)

# %%
df['sex'].value_counts()
# Out:
# sex
# MALE      169
# FEMALE    165
# Name: count, dtype: int64

# %%
df['sex'] = df['sex'].fillna(df['sex'].mode()[0])
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000         18.70000         181.000000
# 1    Adelie  Torgersen          39.50000         17.40000         186.000000
# 2    Adelie  Torgersen          40.30000         18.00000         195.000000
# 3    Adelie  Torgersen          43.92193         17.15117         200.915205
# 4    Adelie  Torgersen          36.70000         19.30000         193.000000
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193         17.15117         200.915205
# 340  Gentoo     Biscoe          46.80000         14.30000         215.000000
# 341  Gentoo     Biscoe          50.40000         15.70000         222.000000
# 342  Gentoo     Biscoe          45.20000         14.80000         212.000000
# 343  Gentoo     Biscoe          49.90000         16.10000         213.000000
#
#      body_mass_g     sex
# ...

# %%
df.isna().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# # Encoding

# %%
df= pd.get_dummies(df,columns =['island','sex'], drop_first =True ,dtype=int)
df
# Out:
#     species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie          39.10000         18.70000         181.000000
# 1    Adelie          39.50000         17.40000         186.000000
# 2    Adelie          40.30000         18.00000         195.000000
# 3    Adelie          43.92193         17.15117         200.915205
# 4    Adelie          36.70000         19.30000         193.000000
# ..      ...               ...              ...                ...
# 339  Gentoo          43.92193         17.15117         200.915205
# 340  Gentoo          46.80000         14.30000         215.000000
# 341  Gentoo          50.40000         15.70000         222.000000
# 342  Gentoo          45.20000         14.80000         212.000000
# 343  Gentoo          49.90000         16.10000         213.000000
#
#      body_mass_g  island_Dream  island_Torgersen  sex_MALE
# 0    3750.000000             0                 1         1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()
df['species'] = le.fit_transform(df['species'])
df
# Out:
#      species  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0          39.10000         18.70000         181.000000
# 1          0          39.50000         17.40000         186.000000
# 2          0          40.30000         18.00000         195.000000
# 3          0          43.92193         17.15117         200.915205
# 4          0          36.70000         19.30000         193.000000
# ..       ...               ...              ...                ...
# 339        2          43.92193         17.15117         200.915205
# 340        2          46.80000         14.30000         215.000000
# 341        2          50.40000         15.70000         222.000000
# 342        2          45.20000         14.80000         212.000000
# 343        2          49.90000         16.10000         213.000000
#
#      body_mass_g  island_Dream  island_Torgersen  sex_MALE
# 0    3750.000000             0                 1         1
# ...

# %%
X = df.drop(['species'], axis=1)
y = df['species']

# %%
X
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0            39.10000         18.70000         181.000000  3750.000000
# 1            39.50000         17.40000         186.000000  3800.000000
# 2            40.30000         18.00000         195.000000  3250.000000
# 3            43.92193         17.15117         200.915205  4201.754386
# 4            36.70000         19.30000         193.000000  3450.000000
# ..                ...              ...                ...          ...
# 339          43.92193         17.15117         200.915205  4201.754386
# 340          46.80000         14.30000         215.000000  4850.000000
# 341          50.40000         15.70000         222.000000  5750.000000
# 342          45.20000         14.80000         212.000000  5200.000000
# 343          49.90000         16.10000         213.000000  5400.000000
#
#      island_Dream  island_Torgersen  sex_MALE
# 0               0                 1         1
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 339    2
# 340    2
# 341    2
# 342    2
# 343    2
# Name: species, Length: 344, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=True)

# %%
df.to_excel('peniguncleandata.xlsx',index=False)
